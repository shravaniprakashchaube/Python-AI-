# %%
# numeric: int, float,complex
# str: " " ' '
# List [ ]
# Tuple ( )
# Set {atleast 1 value}
# dict {key:value}

# %% [markdown]
# # **String**

# %%
a = 'this is python'
a
# Out:
# 'this is python'

# %%
# int a = 100
# string s = 'sample'
# this is static typing

# %%
# python is a dynamically typed language
# python understands its data type at runtime, user need to add data type implicitly in a code

# %%
a
# Out:
# 'this is python'

# %%
a.upper()
# Out:
# 'THIS IS PYTHON'

# %%
'shravani'.upper()
# Out:
# 'SHRAVANI'

# %%
# to get the information of any method or any process valid in python
# we can use help() function
help(a.upper)
# Out:
# Help on built-in function upper:
#
# upper() method of builtins.str instance
#     Return a copy of the string converted to uppercase.

# %%
help(a.count)
# Out:
# Help on built-in function count:
#
# count(...) method of builtins.str instance
#     S.count(sub[, start[, end]]) -> int
#
#     Return the number of non-overlapping occurrences of substring sub in
#     string S[start:end].  Optional arguments start and end are
#     interpreted as in slice notation.

# %%
a
# Out:
# 'this is python'

# %%
# to check count of any char/word or substring we can use count()
a.count('i')
# Out:
# 2

# %%
a.count('I') # python is case sensitive
# Out:
# 0

# %%
help(str.upper)
# Out:
# Help on method_descriptor:
#
# upper(self, /) unbound builtins.str method
#     Return a copy of the string converted to uppercase.

# %%
a
# Out:
# 'this is python'

# %%
# the output is temp. means it is not updating the original object
# i wnt to make the first letter of staring str in captial
a.capitalize()
# Out:
# 'This is python'

# %%
# to make each initial letter in caps we will use title()
a.title()
# Out:
# 'This Is Python'

# %%
a
# Out:
# 'this is python'

# %%
# check total blocks present in str
len(a)
# Out:
# 14

# %%
#t h i s  i s  p y t h o n
#0 1 2.........

# %%
# Str supports indexing
# indexing means a dedicated number allocated to each block of a string

# %%
a
# Out:
# 'this is python'

# %%
# to use index we have take [ ] square bracket
#a[index]
a[0]
# Out:
# 't'

# %%
# we have +ve and -ve index as well
# +ve indexing starts with Zero- Left to Right
# -ve indexing starts with -1 - Right to Left

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a
# Out:
# 'this is python'

# %%
a[13],a[-1]
# Out:
# ('n', 'n')

# %%
# Using indexing we can access one element at a time
# But if we want to access multiple elements/blocks then use slicing

# %%
a
# Out:
# 'this is python'

# %%
# slicing [start_index:stop_index]
a[0:4]
# Out:
# 'this'

# %%
# access python
a[8:14]
# Out:
# 'python'

# %%
a[:]
# Out:
# 'this is python'

# %%
a[8:14]
# Out:
# 'python'

# %%
a[2:7]
# Out:
# 'is is'

# %%
# i want to print python in negative index , how to do that ?
a[-7:]
# Out:
# ' python'

# %%
p = 'PRASAD'
p[-3]
# Out:
# 'S'

# %%
p[-3:]
# Out:
# 'SAD'

# %%
# Intereste in AI
