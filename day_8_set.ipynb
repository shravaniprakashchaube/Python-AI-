# %% [markdown]
# # **Set & Dictionary**

# %%
# Both are mutable data types
# set- {at least one element inside}

# %%
s = {}
type(s)
# Out:
# dict

# %%
s1 = {1,}
type(s1)
# Out:
# set

# %%
# Features of set
# duplicates are not allowed
p = {1,2,3,4,1,1,1,3,3,3,4,4,2,2,2}
p
# Out:
# {1, 2, 3, 4}

# %%
# Does'nt preserves sequence order
q = {1,290,'3',4,1,1,'A',3,3,'B',4,4,'Python',2,2,0}
q
# Out:
# {0, 1, 2, 290, 3, '3', 4, 'A', 'B', 'Python'}

# %%
s={'Za11.5','Ba','Ab','C',2,2,'299',2,1,1,1,3,3,3,3,5,'5abc',5,4,4,4,9,9,9,7,8,8}
s
# Out:
# {1, 2, '299', 3, 4, 5, '5abc', 7, 8, 9, 'Ab', 'Ba', 'C', 'Za11.5'}

# %%
# Background data structure of a set is a Hash Table
# Hash table doesnt support indexing and slicing

# %%
# Set is Mutable
s
# Out:
# {1, 2, '299', 3, 4, 5, '5abc', 7, 8, 9, 'Ab', 'Ba', 'C', 'Za11.5'}

# %%
# try to delete members of a set
s.pop()
# Out:
# 1

# %%
s
# Out:
# {2, '299', 3, 4, 5, '5abc', 7, 8, 9, 'Ab', 'Ba', 'C', 'Za11.5'}

# %%
s.pop()
# Out:
# 2

# %%
help(s.pop)
# Out:
# Help on built-in function pop:
#
# pop(...) method of builtins.set instance
#     Remove and return an arbitrary set element.
#     Raises KeyError if the set is empty.

# %%
lot = {1122,3122,4355,6711,2934}

# %%
winner = lot.pop()
winner
# Out:
# 4355

# %%
lot
# Out:
# {2934, 3122, 6711}

# %%
print('Original lot:',lot)
out = lot.pop()
print('Element removed:',out,'Current set:',lot)
# Out:
# Original lot: {3122, 2934, 6711}
# Element removed: 3122 Current set: {2934, 6711}

# %%
# remove(value)
help(s.remove)
# Out:
# Help on built-in function remove:
#
# remove(...) method of builtins.set instance
#     Remove an element from a set; it must be a member.
#
#     If the element is not a member, raise a KeyError.

# %%
p
# Out:
# {1, 2, 3, 4}

# %%
p.remove(4)

# %%
p
# Out:
# {1, 2, 3}

# %%
# if we try to remove an element which is not present
p.remove('java')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1947858643.py in <cell line: 0>()
#       1 # if we try to remove an element which is not present
# ----> 2 p.remove('java')
#
# KeyError: 'java'

# %%
x = {'A','B','C'}
x
# Out:
# {'A', 'B', 'C'}

# %%
# pop()
x.pop()  # returns an element which it removes
# Out:
# 'B'

# %%
x
# Out:
# {'A', 'C'}

# %%
x.remove('B') # B is already removed n not present in x
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2732373068.py in <cell line: 0>()
# ----> 1 x.remove('B') # B is already removed n not present in x
#
# KeyError: 'B'

# %%
x.remove('C')  # it is not returning an element, just removes it

# %%
x
# Out:
# {'A'}

# %%
# Assignment: Check all the methods of a Set
