# %% [markdown]
# # **Transfer statements**

# %%
l2=[1999,235,8444,3221,500,100,3999]
for i in l2:
    if i<500:
       print("Actual amount is Rs.",i," with no delivery charge")
       continue
    else:
        print("Actual amount is Rs. ", i," with delivery charge or Rs.70/- Total amount is: Rs.", i+70)
# Out:
# Actual amount is Rs.  1999  with delivery charge or Rs.70/- Total amount is: Rs. 2069
# Actual amount is Rs. 235  with no delivery charge
# Actual amount is Rs.  8444  with delivery charge or Rs.70/- Total amount is: Rs. 8514
# Actual amount is Rs.  3221  with delivery charge or Rs.70/- Total amount is: Rs. 3291
# Actual amount is Rs.  500  with delivery charge or Rs.70/- Total amount is: Rs. 570
# Actual amount is Rs. 100  with no delivery charge
# Actual amount is Rs.  3999  with delivery charge or Rs.70/- Total amount is: Rs. 4069

# %%
500<500
# Out:
# False

# %%
def test():
  #print(1)
  return 10

# %%
result = test()
def process(result):
  print("Final answer is:",result+100)

process(result)
# Out:
# Final answer is: 110

# %%
# pass - is used to create empty blocks
if 1<4:
  pass

# %%
def debit():
  pass
def credit():
  pass
def online():
  pass

# %% [markdown]
# # **Modules in Python**

# %%
# a file with .py extension is a python file and it is called as a module
# 2 types of module
# 1. Built-in module
#2. User defined module

# %%
# How to use built in module
# we need to use import keyword for to access members of that module
# import module_name
import math

# %%
math.pi  # we are using . dot operator to access members of a module
# Out:
# 3.141592653589793

# %%
math.factorial(3)
# Out:
# 6

# %%
# to check the built in modules use help
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Unable to import `black` from betterproto plugin! Please ensure that you've installed betterproto as `pip install "betterproto[compiler]"` so that compiler dependencies are included.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/betterproto/plugin/compiler.py", line 6, in <module>
#     import black
# ModuleNotFoundError: No module named 'black'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipython-input-1377614110.py", line 2, in <cell line: 0>
#     help('modules')
#   File "<frozen _sitebuiltins>", line 103, in __call__
# ...

# %% [markdown]
# 1.   math
# 2.  datetime
# 3.  csv
# 4. time
# 5. os
# 6. sys
# 7. random
# 8. json

# %%
# create a test.py and add 3 members in and n try to access those members
import test

# %%
test.add()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1650994571.py in <cell line: 0>()
# ----> 1 test.add()
#
# AttributeError: module 'test' has no attribute 'add'
