# %%
#  Domain Knowledge
# SME - Subject Matter Expert
# Data Science Libraries
# Numpy - Numeric Python
# Pandas -  Data Analysis
# Matplotlib - Data Viz. plot
# Seaborn - Data Viz. plot

# %%
import seaborn as sns

# %%
# load data
p = sns.load_dataset('penguins')
p
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
# fetch summary of dataset
p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
# check statistical data for all numeric columns
p.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
# display column list
p.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
# show unique species
p['species'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
# caterywise count for species
p['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
p[['species','sex']].value_counts()
# Out:
# species    sex
# Adelie     Female    73
#            Male      73
# Gentoo     Male      61
#            Female    58
# Chinstrap  Male      34
#            Female    34
# Name: count, dtype: int64

# %%
# count plot for island column
sns.countplot(x='island',data=p,palette='BrBG')
# Out:
# /tmp/ipython-input-230/961897615.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='island',data=p,palette='BrBG')
# <Axes: xlabel='island', ylabel='count'>

# %%
import matplotlib.pyplot as plt

sns.countplot(x='island',data=p,hue='sex',palette='rainbow')
plt.title('Ye Penguin ka plot hai')
# Out:
# Text(0.5, 1.0, 'Ye Penguin ka plot hai')

# %%
p[:2]
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female

# %%
# avg body mass
p['body_mass_g'].mean()
# Out:
# np.float64(4201.754385964912)

# %%
p[['species','sex']].value_counts(normalize=True)
# Out:
# species    sex
# Adelie     Female    0.219219
#            Male      0.219219
# Gentoo     Male      0.183183
#            Female    0.174174
# Chinstrap  Male      0.102102
#            Female    0.102102
# Name: proportion, dtype: float64
